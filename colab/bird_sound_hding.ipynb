# %% [markdown]
# # Bird Sound Recognize

# %% [markdown]
# ## Value Setting

# %% [markdown]
# ### Mount at Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Train Value

# %%
SOUND_PATH = r"/content/gdrive/MyDrive/Colab Notebooks/bird-sound/Bird_sound/dataset/raw"
DATASET_PATH = r"/content/gdrive/MyDrive/Colab Notebooks/bird-sound/Bird_sound/dataset/Tyler_data"
WAV_PATH = r""

MODEL_NAME = "Model_10Epochs_v3"

TIME_STEP = 20
SOUND_LENGTH = 128
TEST_DATA_RATIO = 0.2
INPUT_SHAPE = (TIME_STEP, SOUND_LENGTH)
CLASSES = ["before_net", "build_net", "fail", "hug_egg", "out_net", "spawn", "yu_zhu_gi"]

MODEL_CONV1DS = [32, 32]
MODEL_LAYERS = [64, 128, 0, 32, 64]

BATCH_SIZE = 50
EPOCHS = 10

# %% [markdown]
# ## Prepare All Tool

# %%
# https://blog.csdn.net/weixin_44414948/article/details/114903215?spm=1001.2101.3001.6650.1&utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7ECTRLIST%7ERate-1.pc_relevant_default&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7ECTRLIST%7ERate-1.pc_relevant_default
import h5py
print(h5py.__version__)
# Out:
# 2.10.0

# %% [markdown]
# ### Prepare Package

# %%
# !pip uninstall h5py -y
# !pip install h5py==2.10 -i https://pypi.tuna.tsinghua.edu.cn/simple/
# Out:
# Found existing installation: h5py 2.10.0
# Uninstalling h5py-2.10.0:
#   Successfully uninstalled h5py-2.10.0
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Collecting h5py==2.10
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/3f/c0/abde58b837e066bca19a3f7332d9d0493521d7dd6b48248451a9e3fe2214/h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10) (1.21.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10) (1.15.0)
# Installing collected packages: h5py
# Successfully installed h5py-2.10.0

# %%
# %tensorflow_version 1.x
import os
import random
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPool1D, Flatten, Dropout
from tensorflow.keras.layers import Input, TimeDistributed, Dense
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import json
import librosa
import random
import pickle
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# ### Sound Proccess Tool

# %%
class SoundProcessor:
    def __init__(self):
        self.data = []
        self.sr = None

    def load_sound(self, path):
        self.data, self.sr = librosa.load(path)
        return self.data

    def transform_mfcc(self, data):
        mfcc = librosa.feature.mfcc(y=data, sr=self.sr, n_mfcc=SOUND_LENGTH)
        arr = mfcc.T
        arr = arr[np.shape(arr)[0] % TIME_STEP:, :]
        return arr

    def bird_sound_all_classes_json(self, load_folder, save_path):
        if not os.path.exists(save_path):
            os.mkdir(save_path)
        for folder in os.listdir(load_folder):
            load_path = os.path.join(load_folder, folder)
            folderData = []
            for filename in os.listdir(os.path.join(load_path)):
                data = self.load_sound(os.path.join(load_path, filename))
                mfccArr = self.transform_mfcc(data)
                if mfccArr.shape[0] < TIME_STEP:
                    print(filename, "arr is too short, ignored.", mfccArr.shape)
                    continue
                for subArr in np.split(mfccArr, mfccArr.shape[0] // TIME_STEP):
                    # print("test")
                    # print(len(subArr[0]))
                    folderData.append(subArr.tolist())
                print(filename, " done.")
            split_idx = max(1, int(len(folderData) * TEST_DATA_RATIO))
            random.shuffle(folderData)
            test_arr = folderData[:split_idx]
            train_arr = folderData[split_idx:]
            # print(test_arr)
            # print(train_arr)
            filename = os.path.join(save_path, folder + ".json")
            with open(filename, "w") as f:
                print(np.array(test_arr).shape)
                print(np.array(train_arr).shape)
                data = {"test": test_arr, "train": train_arr}
                json.dump(data, f)
            print(folder + ".json", " saved.  \n", "Located: ", filename)

        print("Every folder have done!")
        print(f"Save at path: {save_path}")
        print("==================================================================================================")

    def bird_sound_all_classes_npy(self, load_folder, save_path):
        if not os.path.exists(save_path):
            os.mkdir(save_path)
        for folder in os.listdir(load_folder):
            load_path = os.path.join(load_folder, folder)
            folderData = []
            for filename in os.listdir(os.path.join(load_path)):
                data = self.load_sound(os.path.join(load_path, filename))
                mfccArr = self.transform_mfcc(data)
                if mfccArr.shape[0] < TIME_STEP:
                    print(filename, "arr is too short, ignored.", mfccArr.shape)
                    continue
                for subArr in np.split(mfccArr, mfccArr.shape[0] // TIME_STEP):
                    folderData.append(subArr)
                print(filename, " done.")
            split_idx = max(1, int(len(folderData) * TEST_DATA_RATIO))
            test_arr = folderData[:split_idx]
            train_arr = folderData[split_idx:]
            random.shuffle(folderData)
            test_npy_folder = os.path.join(save_path, "test")
            train_npy_folder = os.path.join(save_path, "train")
            if not os.path.exists(test_npy_folder):
                os.mkdir(test_npy_folder)
            if not os.path.exists(train_npy_folder):
                os.mkdir(train_npy_folder)
            test_npy_filename = os.path.join(test_npy_folder, folder + ".npy")
            train_npy_filename = os.path.join(train_npy_folder, folder + ".npy")
            np.save(test_npy_filename, np.asarray(test_arr))
            # print(test_arr)
            np.save(train_npy_filename, np.asarray(train_arr))
            print(test_npy_filename, "saved. length:", TIME_STEP, " x ", SOUND_LENGTH)
            print(train_npy_filename, "saved. length:", TIME_STEP, " x ", SOUND_LENGTH)

        print("Every folder have done!")
        print(f"Save at path: {save_path}")
        print("==================================================================================================")

    def instant_transform(self, data):
        mfccArr = self.transform_mfcc(data)
        if mfccArr.shape[0] < TIME_STEP:
            print("Video is too short, can't recognize.")
            return np.array([])
        queue = [subArr for subArr in np.split(mfccArr, mfccArr.shape[0] // TIME_STEP)]
        return np.array(queue)

    def load_json(self, load_folder):
        x_train = []
        y_train = []
        x_test = []
        y_test = []
        for y, filename in enumerate(os.listdir(os.path.join(load_folder, "JSON"))):
            load_path = os.path.join(load_folder, "JSON", filename)
            print(load_path)
            data = json.load(open(load_path))
            print(f"{filename} have loaded.")
            x_test += data["test"]
            x_train += data["train"]
            for i in range(len(data["test"])):
                y_test.append(y)
            for i in range(len(data["train"])):
                y_train.append(y)

        return np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

    def load_npy(self, load_folder):
        x_train = []
        y_train = []
        x_test = []
        y_test = []
        for y, filename in enumerate(os.listdir(os.path.join(load_folder, "NPY", "train"))):
            load_path = os.path.join(load_folder, "NPY", "train", filename)
            print(load_path)
            data = np.load(load_path, allow_pickle=True)
            print(f"{filename} have loaded, shape: ", data.shape)
            x_train += data.tolist()
            for i in range(data.shape[0]):
                y_train.append(y)

        for y, filename in enumerate(os.listdir(os.path.join(load_folder, "NPY", "test"))):
            load_path = os.path.join(load_folder, "NPY", "test", filename)
            print(load_path)
            data = np.load(load_path, allow_pickle=True)
            print(f"{filename} have loaded, shape: ", data.shape)
            x_test += data.tolist()
            for i in range(data.shape[0]):
                y_test.append(y)
        return np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

# %% [markdown]
# ### Model Create Tool

# %% [markdown]
# #### Classes TransForm

# %%
def classes_change(mode):
    for i, C in enumerate(CLASSES):
        if i == mode:
            return C
    return "None"

# %% [markdown]
# #### Create Model

# %%
def createConv1DModel(
        name,
        n_conv1Ds,
        n_layers,
        d_input,
        n_classes):
    """
    @param name: model name
    @param n_conv1Ds: filters of conv1D
    @param n_layers: filters of dense
    @param d_input: input shape
    @param n_classes: output classes
    @return: model
    """

    model = Sequential(name=f"{name}")
    model.add(Conv1D(128, kernel_size=3, input_shape=d_input, activation="relu"))
    model.add(MaxPool1D(pool_size=2))
    for i in n_conv1Ds[1:]:
        if i == 0:
            model.add(Dropout(0.2))
        else:
            model.add(Conv1D(i, kernel_size=3, activation="relu"))
            model.add(MaxPool1D(pool_size=2))
    model.add(Flatten())
    for i in n_layers:
        if i == 0:
            model.add(Dropout(0.2))
        else:
            model.add(Dense(i, activation="relu"))
    model.add(Dense(len(n_classes), activation="softmax"))
    model.summary()
    return model

# %% [markdown]
# #### Get Model

# %%
def get_model():
    return createConv1DModel("model",
                  MODEL_CONV1DS,
                  MODEL_LAYERS,
                  INPUT_SHAPE,
                  CLASSES,
                  )

# %% [markdown]
# #### Model Basic Functions

# %%
def setting(model):
    # tf.random.set_seed(120)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def fit(model, x_train, y_train, x_test, y_test, batch, epochs):
    y_train = to_categorical(y_train, 7)
    y_test = to_categorical(y_test, 7)
    print("START TRAINING==================================================================")
    train_history = model.fit(x=x_train, y=y_train,
                              validation_split=0.2,
                              epochs=epochs,
                              batch_size=batch,
                              verbose=2,
                              validation_data=(x_test, y_test),
                              shuffle=True,
                              )
    return model, train_history

def save(model, save_path, name):
    if not os.path.exists(save_path):
        os.mkdir(save_path)
    model.save(os.path.join(save_path, name+".h5"))
    print("Model have saved.")

def load(save_path):
    model = keras.models.load_model(save_path+".h5")
    model.summary()
    return model

# %% [markdown]
# #### Predict Function

# %%
def predict_classes(model, data):
    prediction = [np.argmax(arr) for arr in model.predict(data)]
    predict_class = [classes_change(arr) for arr in prediction]
    return prediction, predict_class

# %% [markdown]
# #### Test Function

# %%
def find_max(list_obj):
    max_length = 0
    for s in list_obj:
        if len(s) > max_length:
            max_length = len(s)
    return max_length

def fill_string(str_obj, max_length):
    fill_times = max_length - len(str_obj)
    str_obj += " " * fill_times
    return str_obj

def test(model, x_test, y_test, test_time=10):
    correct_rate = 0.0
    correct_times = 0
    fail_times = 0
    predict = model.predict(x_test)
    test_time = min(test_time, len(predict))
    test_id = [i for i in range(len(predict))]
    cls = [classes_change(i) for i in range(6)]
    max_length = find_max(cls)
    print(max_length)
    for i in range(test_time):
        index = random.choice(test_id)
        test_id.remove(index)
        prediction = np.argmax(predict[index])
        if classes_change(prediction) == classes_change(y_test[index]):
            correct_times += 1
            correct_rate += 1
        else:
            fail_times += 1

        output = f"test{i+1}\t| prediction: " + fill_string(classes_change(prediction), max_length)
        print(output, "\t| answer: ", classes_change(y_test[index]))
    correct_rate = (correct_rate / test_time) * 100
    print("\nAccuracy=%.2f%%" % correct_rate)
    print(f"Fail Times: {fail_times}, Correct Times: {correct_times}")

# %% [markdown]
# #### Plot Model's Accuracy & Loss

# %%
def load_history(load_path, name):
    if not os.path.exists(load_path):
      os.mkdir(load_path)
    with open(os.path.join(load_path, name+"_history.p"), 'rb') as f:
        history = pickle.load(f)
    print("History have loaded")
    return history


def save_history(history, save_path, name):
    history = history.history
    if not os.path.exists(save_path):
      os.mkdir(save_path)
    with open(os.path.join(save_path, name+"_history.p"), 'wb') as f:
        pickle.dump(history, f)
    print("History have saved")


def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name, is_save=True, save_path=""):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''

    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]

    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))
    # Plot the Graph.
    fig = plt.figure()
    plt.plot(epochs, metric_value_1, 'blue', label=metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label=metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()
    plt.show()
    if is_save and save_path != "":
        fig.savefig(save_path+".png")

def plot_all(model_training_history):
  plot_metric(model_training_history, "loss", "val_loss", "Train Loss Vs Train Val Loss",
        True, os.path.join(DATASET_PATH, "MODEL", MODEL_NAME + "_loss"))
  plot_metric(model_training_history, "acc", "val_acc", "Train Acc Vs Train Val Acc",
        True, os.path.join(DATASET_PATH, "MODEL", MODEL_NAME + "_acc"))

# %%
def plot(history, save_path, name):
    if not os.path.exists(save_path):
        os.mkdir(save_path)
    print(history.history.keys())
    fig = plt.figure()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig(os.path.join(save_path, f"{name}_accuracy.png"))

    fig = plt.figure()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig(os.path.join(save_path, f"{name}_loss.png"))

# %% [markdown]
# ### Main wav proccess

# %%
def main_wav_process(mode):
    soundTool = SoundProcessor()
    if mode == "npy":
        soundTool.bird_sound_all_classes_npy(SOUND_PATH, os.path.join(DATASET_PATH, "NPY"))
    elif mode == "json":
        soundTool.bird_sound_all_classes_json(SOUND_PATH, os.path.join(DATASET_PATH, "JSON"))

# %% [markdown]
# ### Data Loader

# %%
def data_loader(mode):
    soundTool = SoundProcessor()
    if mode == "npy":
        x_train, y_train, x_test, y_test = soundTool.load_npy(DATASET_PATH)
    elif mode == "json":
        x_train, y_train, x_test, y_test = soundTool.load_json(DATASET_PATH)
    else:
        print("Please choice data type.")
        return
    return x_train, y_train, x_test, y_test

# %% [markdown]
# ### Main Training

# %%
def main_training(x_train, y_train, x_test, y_test):
    print("x_train: ", x_train.shape)
    print("y_train: ", y_train.shape)
    print("x_test: ", x_test.shape)
    print("y_test: ", y_test.shape)
    model = get_model()
    model = setting(model)
    model, history = fit(model,
                x_train, y_train,
                x_test, y_test,
                BATCH_SIZE,
                EPOCHS,
                )
    model.save(os.path.join(DATASET_PATH, "MODEL", MODEL_NAME + '.h5'))
    # save(model, os.path.join(DATASET_PATH, "MODEL"), MODEL_NAME)
    plot_all(history)
    save_history(history, os.path.join(DATASET_PATH, "HISTORY"), MODEL_NAME)

# %% [markdown]
# ### Main Testing

# %%
def main_testing(x_test, y_test):
    model = load(os.path.join(DATASET_PATH, "MODEL", MODEL_NAME))
    test(model, x_test, y_test, 150)

# %% [markdown]
# ### Main Test wav

# %%
def main_test_wav(wav_path):
    model = load(os.path.join(DATASET_PATH, "MODEL", MODEL_NAME))
    soundTool = SoundProcessor()
    data = soundTool.load_sound(wav_path)
    mfccData = soundTool.instant_transform(data)
    if mfccData.shape[0] != np.array([]).shape[0]:
        predictions, classes = predict_classes(model, mfccData)
        print("Prediction: ", max(classes))

# %% [markdown]
# ## Main

# %%
# main_wav_process("npy")
# main_wav_process("json")
x_train, y_train, x_test, y_test = data_loader("json")
main_training(x_train, y_train, x_test, y_test)
# save_history(history.history, os.path.join(DATASET_PATH, "HISTORY"), MODEL_NAME)
main_testing(x_test, y_test)
# main_test_wav(WAV_PATH)
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/bird-sound/Bird_sound/dataset/Tyler_data/JSON/before_net.json
# before_net.json have loaded.
# /content/gdrive/MyDrive/Colab Notebooks/bird-sound/Bird_sound/dataset/Tyler_data/JSON/build_nest.json
# build_nest.json have loaded.
# /content/gdrive/MyDrive/Colab Notebooks/bird-sound/Bird_sound/dataset/Tyler_data/JSON/fail.json
# fail.json have loaded.
# /content/gdrive/MyDrive/Colab Notebooks/bird-sound/Bird_sound/dataset/Tyler_data/JSON/hug_egg.json
# hug_egg.json have loaded.
# /content/gdrive/MyDrive/Colab Notebooks/bird-sound/Bird_sound/dataset/Tyler_data/JSON/out_nest.json
# out_nest.json have loaded.
# /content/gdrive/MyDrive/Colab Notebooks/bird-sound/Bird_sound/dataset/Tyler_data/JSON/spawn.json
# spawn.json have loaded.
# /content/gdrive/MyDrive/Colab Notebooks/bird-sound/Bird_sound/dataset/Tyler_data/JSON/yu_zhu_qi.json
# yu_zhu_qi.json have loaded.
# x_train:  (8101, 20, 128)
# y_train:  (8101,)
# x_test:  (2021, 20, 128)
# y_test:  (2021,)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 18, 128)           49280
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 9, 128)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 7, 32)             12320
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 3, 32)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 96)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                6208
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_9 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 82,823
# Trainable params: 82,823
# Non-trainable params: 0
# _________________________________________________________________
# START TRAINING==================================================================
# Train on 8101 samples, validate on 2021 samples
# Epoch 1/10
# 8101/8101 - 1s - loss: 1.5468 - acc: 0.4523 - val_loss: 1.1966 - val_acc: 0.6353
# Epoch 2/10
# 8101/8101 - 1s - loss: 0.8472 - acc: 0.6795 - val_loss: 0.7371 - val_acc: 0.7190
# Epoch 3/10
# 8101/8101 - 1s - loss: 0.6007 - acc: 0.7805 - val_loss: 0.5837 - val_acc: 0.7773
# Epoch 4/10
# 8101/8101 - 1s - loss: 0.4664 - acc: 0.8293 - val_loss: 0.4601 - val_acc: 0.8323
# Epoch 5/10
# 8101/8101 - 1s - loss: 0.3904 - acc: 0.8584 - val_loss: 0.6038 - val_acc: 0.7798
# Epoch 6/10
# 8101/8101 - 1s - loss: 0.3852 - acc: 0.8584 - val_loss: 0.4288 - val_acc: 0.8550
# Epoch 7/10
# 8101/8101 - 1s - loss: 0.3009 - acc: 0.8905 - val_loss: 0.4151 - val_acc: 0.8540
# Epoch 8/10
# 8101/8101 - 1s - loss: 0.2628 - acc: 0.9040 - val_loss: 0.3400 - val_acc: 0.8808
# Epoch 9/10
# 8101/8101 - 1s - loss: 0.2457 - acc: 0.9133 - val_loss: 0.5970 - val_acc: 0.8149
# Epoch 10/10
# 8101/8101 - 1s - loss: 0.5449 - acc: 0.8101 - val_loss: 0.4470 - val_acc: 0.8521
# History have saved
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 18, 128)           49280
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 9, 128)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 7, 32)             12320
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 3, 32)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 96)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                6208
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_9 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 82,823
# Trainable params: 82,823
# Non-trainable params: 0
# _________________________________________________________________
# 10
# test1	| prediction: fail       	| answer:  fail
# test2	| prediction: spawn      	| answer:  spawn
# test3	| prediction: fail       	| answer:  fail
# test4	| prediction: hug_egg    	| answer:  hug_egg
# test5	| prediction: out_net    	| answer:  out_net
# test6	| prediction: fail       	| answer:  fail
# test7	| prediction: build_net  	| answer:  hug_egg
# test8	| prediction: spawn      	| answer:  spawn
# test9	| prediction: spawn      	| answer:  spawn
# test10	| prediction: out_net    	| answer:  out_net
# test11	| prediction: fail       	| answer:  yu_zhu_gi
# test12	| prediction: out_net    	| answer:  out_net
# test13	| prediction: build_net  	| answer:  build_net
# test14	| prediction: build_net  	| answer:  build_net
# test15	| prediction: build_net  	| answer:  build_net
# test16	| prediction: before_net 	| answer:  before_net
# test17	| prediction: before_net 	| answer:  before_net
# test18	| prediction: out_net    	| answer:  out_net
# test19	| prediction: spawn      	| answer:  spawn
# test20	| prediction: build_net  	| answer:  build_net
# test21	| prediction: spawn      	| answer:  spawn
# test22	| prediction: hug_egg    	| answer:  hug_egg
# test23	| prediction: spawn      	| answer:  spawn
# test24	| prediction: hug_egg    	| answer:  hug_egg
# test25	| prediction: out_net    	| answer:  yu_zhu_gi
# test26	| prediction: yu_zhu_gi  	| answer:  yu_zhu_gi
# test27	| prediction: before_net 	| answer:  before_net
# test28	| prediction: yu_zhu_gi  	| answer:  yu_zhu_gi
# test29	| prediction: hug_egg    	| answer:  hug_egg
# test30	| prediction: hug_egg    	| answer:  fail
# test31	| prediction: out_net    	| answer:  out_net
# test32	| prediction: before_net 	| answer:  before_net
# test33	| prediction: hug_egg    	| answer:  hug_egg
# test34	| prediction: fail       	| answer:  fail
# test35	| prediction: hug_egg    	| answer:  hug_egg
# test36	| prediction: spawn      	| answer:  spawn
# test37	| prediction: fail       	| answer:  hug_egg
# test38	| prediction: hug_egg    	| answer:  hug_egg
# test39	| prediction: before_net 	| answer:  before_net
# test40	| prediction: build_net  	| answer:  fail
# test41	| prediction: hug_egg    	| answer:  hug_egg
# test42	| prediction: before_net 	| answer:  before_net
# test43	| prediction: out_net    	| answer:  out_net
# test44	| prediction: build_net  	| answer:  build_net
# test45	| prediction: fail       	| answer:  fail
# test46	| prediction: build_net  	| answer:  before_net
# test47	| prediction: before_net 	| answer:  before_net
# test48	| prediction: hug_egg    	| answer:  before_net
# test49	| prediction: build_net  	| answer:  before_net
# test50	| prediction: before_net 	| answer:  before_net
# test51	| prediction: out_net    	| answer:  out_net
# test52	| prediction: hug_egg    	| answer:  hug_egg
# test53	| prediction: build_net  	| answer:  hug_egg
# test54	| prediction: hug_egg    	| answer:  hug_egg
# test55	| prediction: out_net    	| answer:  out_net
# test56	| prediction: out_net    	| answer:  out_net
# test57	| prediction: fail       	| answer:  fail
# test58	| prediction: fail       	| answer:  fail
# test59	| prediction: hug_egg    	| answer:  hug_egg
# test60	| prediction: fail       	| answer:  fail
# test61	| prediction: build_net  	| answer:  build_net
# test62	| prediction: out_net    	| answer:  out_net
# test63	| prediction: before_net 	| answer:  before_net
# test64	| prediction: out_net    	| answer:  out_net
# test65	| prediction: fail       	| answer:  fail
# test66	| prediction: fail       	| answer:  build_net
# test67	| prediction: fail       	| answer:  hug_egg
# test68	| prediction: hug_egg    	| answer:  hug_egg
# test69	| prediction: before_net 	| answer:  before_net
# test70	| prediction: before_net 	| answer:  before_net
# test71	| prediction: build_net  	| answer:  build_net
# test72	| prediction: build_net  	| answer:  fail
# test73	| prediction: out_net    	| answer:  out_net
# test74	| prediction: hug_egg    	| answer:  hug_egg
# test75	| prediction: hug_egg    	| answer:  hug_egg
# test76	| prediction: fail       	| answer:  hug_egg
# test77	| prediction: yu_zhu_gi  	| answer:  before_net
# test78	| prediction: out_net    	| answer:  out_net
# test79	| prediction: hug_egg    	| answer:  hug_egg
# test80	| prediction: out_net    	| answer:  out_net
# test81	| prediction: yu_zhu_gi  	| answer:  yu_zhu_gi
# test82	| prediction: fail       	| answer:  fail
# test83	| prediction: hug_egg    	| answer:  hug_egg
# test84	| prediction: build_net  	| answer:  build_net
# test85	| prediction: out_net    	| answer:  out_net
# test86	| prediction: yu_zhu_gi  	| answer:  yu_zhu_gi
# test87	| prediction: hug_egg    	| answer:  hug_egg
# test88	| prediction: hug_egg    	| answer:  hug_egg
# test89	| prediction: hug_egg    	| answer:  hug_egg
# test90	| prediction: yu_zhu_gi  	| answer:  yu_zhu_gi
# test91	| prediction: hug_egg    	| answer:  hug_egg
# test92	| prediction: hug_egg    	| answer:  hug_egg
# test93	| prediction: spawn      	| answer:  spawn
# test94	| prediction: hug_egg    	| answer:  hug_egg
# test95	| prediction: hug_egg    	| answer:  hug_egg
# test96	| prediction: out_net    	| answer:  out_net
# test97	| prediction: out_net    	| answer:  out_net
# test98	| prediction: out_net    	| answer:  fail
# test99	| prediction: out_net    	| answer:  spawn
# test100	| prediction: hug_egg    	| answer:  hug_egg
# test101	| prediction: out_net    	| answer:  out_net
# test102	| prediction: out_net    	| answer:  out_net
# test103	| prediction: before_net 	| answer:  before_net
# test104	| prediction: before_net 	| answer:  before_net
# test105	| prediction: out_net    	| answer:  out_net
# test106	| prediction: fail       	| answer:  fail
# test107	| prediction: out_net    	| answer:  spawn
# test108	| prediction: out_net    	| answer:  out_net
# test109	| prediction: hug_egg    	| answer:  hug_egg
# test110	| prediction: yu_zhu_gi  	| answer:  yu_zhu_gi
# test111	| prediction: spawn      	| answer:  spawn
# test112	| prediction: out_net    	| answer:  out_net
# test113	| prediction: build_net  	| answer:  build_net
# test114	| prediction: spawn      	| answer:  spawn
# test115	| prediction: hug_egg    	| answer:  hug_egg
# test116	| prediction: out_net    	| answer:  out_net
# test117	| prediction: build_net  	| answer:  build_net
# test118	| prediction: before_net 	| answer:  before_net
# test119	| prediction: hug_egg    	| answer:  hug_egg
# test120	| prediction: spawn      	| answer:  spawn
# test121	| prediction: yu_zhu_gi  	| answer:  yu_zhu_gi
# test122	| prediction: build_net  	| answer:  build_net
# test123	| prediction: hug_egg    	| answer:  hug_egg
# test124	| prediction: fail       	| answer:  build_net
# test125	| prediction: out_net    	| answer:  out_net
# test126	| prediction: out_net    	| answer:  out_net
# test127	| prediction: build_net  	| answer:  build_net
# test128	| prediction: fail       	| answer:  yu_zhu_gi
# test129	| prediction: build_net  	| answer:  build_net
# test130	| prediction: spawn      	| answer:  spawn
# test131	| prediction: before_net 	| answer:  before_net
# test132	| prediction: hug_egg    	| answer:  hug_egg
# test133	| prediction: hug_egg    	| answer:  build_net
# test134	| prediction: fail       	| answer:  fail
# test135	| prediction: build_net  	| answer:  build_net
# test136	| prediction: hug_egg    	| answer:  hug_egg
# test137	| prediction: spawn      	| answer:  spawn
# test138	| prediction: hug_egg    	| answer:  hug_egg
# test139	| prediction: hug_egg    	| answer:  hug_egg
# test140	| prediction: fail       	| answer:  spawn
# test141	| prediction: out_net    	| answer:  out_net
# test142	| prediction: spawn      	| answer:  spawn
# test143	| prediction: build_net  	| answer:  build_net
# test144	| prediction: spawn      	| answer:  spawn
# test145	| prediction: spawn      	| answer:  spawn
# test146	| prediction: yu_zhu_gi  	| answer:  spawn
# test147	| prediction: build_net  	| answer:  build_net
# test148	| prediction: fail       	| answer:  yu_zhu_gi
# test149	| prediction: hug_egg    	| answer:  build_net
# test150	| prediction: build_net  	| answer:  build_net
#
# Accuracy=83.33%
# Fail Times: 25, Correct Times: 125
